# %% [markdown]
# ## EDA (Exploratory Data Analysis): HDI project

# %% [markdown]
# Summary of the data wrangling
#
# The first step of this project has created a cleaned dataset including relevant
# information confirming we have the right data for assessing the most important
# factors impacting Human development index with data for 189 countries. We have
# idenfified our target variable: pov_index for which we will assess the correlation with others factors

# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %% [markdown]
# ### Load the data

# %%
# Loading the data created from the wrangling step
raw_df = pd.read_csv('hdi_wrangling.csv')

# %% [markdown]
# ### Exploring the data

# %%
raw_df.head()
# Out:
#    Unnamed: 0       Country  hdi_2009  hdi_2019  hdi_var  edu_2009  edu_2019  \
# 0           0   Afghanistan     0.460     0.511    0.051       8.9      10.2
# 1           1       Albania     0.733     0.795    0.062      12.3      14.7
# 2           2       Algeria     0.711     0.748    0.037      13.6      14.6
# 3           3       Andorra     0.839     0.868    0.029      11.7      13.3
# 4           4        Angola     0.515     0.581    0.066       9.0      11.8
#
#    edu_var  pov_index
# 0      1.3    0.27200
# 1      2.4    0.00300
# 2      1.0    0.00800
# 3      1.6    0.14129
# 4      2.8    0.28200

# %%
df = raw_df[['Country', 'hdi_2019','hdi_var', 'edu_2019', 'edu_var', 'pov_index']]

# %%
df.describe()
# Out:
#          hdi_2019     hdi_var    edu_2019     edu_var   pov_index
# count  189.000000  189.000000  189.000000  189.000000  189.000000
# mean     0.722423    0.040715   13.326984    0.824599    0.141290
# std      0.149791    0.026742    2.940014    1.000975    0.115049
# min      0.394000   -0.107000    5.000000   -2.999999    0.001000
# 25%      0.602000    0.029000   11.400000    0.300000    0.066000
# 50%      0.740000    0.040715   13.200000    0.800000    0.141290
# 75%      0.829000    0.056000   15.200000    1.300000    0.141290
# max      0.957000    0.113000   22.000000    3.800000    0.590000

# %% [markdown]
# ### Overview of the dependant variable

# %%
# Making a histogram of the hdi_var variable.
df['pov_index'].plot(kind = 'hist' )
plt.xlabel('Poverty index')
# Out:
# Text(0.5, 0, 'Poverty index')

# %%
sns.boxplot( x = df['pov_index'])
# Out:
# <AxesSubplot:xlabel='pov_index'>

# %%
df['hdi_2019'].plot(kind = 'hist')
plt.xlabel('HDI')
# Out:
# Text(0.5, 0, 'HDI')

# %%
df['edu_2019'].plot(kind = 'hist')
plt.xlabel('Education')
# Out:
# Text(0.5, 0, 'Education')

# %% [markdown]
# ### Visualize Relationships between Variables

# %%
# Creating a box plot to spot any outlier

df.corr()
# Out:
#            hdi_2019   hdi_var  edu_2019   edu_var  pov_index
# hdi_2019   1.000000 -0.226686  0.903527  0.009894  -0.539800
# hdi_var   -0.226686  1.000000 -0.113466  0.604425   0.161552
# edu_2019   0.903527 -0.113466  1.000000  0.186468  -0.450020
# edu_var    0.009894  0.604425  0.186468  1.000000   0.164098
# pov_index -0.539800  0.161552 -0.450020  0.164098   1.000000

# %%
sns.pairplot(df)

# %%
# Create a correlation heatmap for looking at the correlation of all variables.
figsize = (40,20)
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [raw]
#  There are 3 notable correlations:
# Positive strong correlation between edu_2019 and hdi_2019 (r = 0.90). However this is normal and only the correlation below linked to change in metrics will be assessed:
# Negative moderate correlation between pov_index and hdi_2019(r = -0.54);
# Negative moderate correlation between pov_index and edu_2019 (r = -0.45);
# Positive strong correlation between edu_var and hdi_var (r = 0.60)

# %%
sns.jointplot(x= 'edu_2019', y = 'pov_index', data= df, kind= 'reg');

# %%
sns.jointplot(x= 'edu_var', y = 'hdi_var', data= df, kind= 'reg');

# %% [markdown]
# From the 2 plots above:
# There is a negative correlation between poverty and education meaning that in case there is a confounder, improving education should result in decreased poverty. Strenght of the relationship between education and HDI (Shown on the 2nd graph above) shows that change in education over years directly positively impact HDI.
# So we can form as null hypothese H0: level of education improves poverty
# Alternative hypothese H1: level of education does not improves poverty

# %% [markdown]
# ## Pre-processing and Training Data Development

# %% [markdown]
#  People are identified as multidimensionally poor if the weighted sum of their deprivations is greater than or equal to a poverty cut off – such as 20%, 30% or 50% of all deprivations. For the purpose of this study, we will consider a treshold of 20%. Based on this criterion, a new column will be created to assess if each country is poor or not

# %%
# Creating a new column to record countries poor or not
import numpy as np
df['pov_class'] = np.where(df['pov_index'] > 0.2,  'poor', 'not poor')
# Out:
# /Users/judith/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.pov_class.value_counts()
# Out:
# not poor    155
# poor         34
# Name: pov_class, dtype: int64

# %%
df.head()
# Out:
#         Country  hdi_2019  hdi_var  edu_2019  edu_var  pov_index pov_class
# 0   Afghanistan     0.511    0.051      10.2      1.3    0.27200      poor
# 1       Albania     0.795    0.062      14.7      2.4    0.00300  not poor
# 2       Algeria     0.748    0.037      14.6      1.0    0.00800  not poor
# 3       Andorra     0.868    0.029      13.3      1.6    0.14129  not poor
# 4        Angola     0.581    0.066      11.8      2.8    0.28200      poor

# %%
# Extracting the list of countries rated poor as per the set criteria of 20%
df[df['pov_class']== 'poor']
# Out:
#                                  Country  hdi_2019   hdi_var  edu_2019  \
# 0                            Afghanistan     0.511  0.051000      10.2
# 4                                 Angola     0.581  0.066000      11.8
# 18                                 Benin     0.545  0.057000      12.6
# 26                          Burkina Faso     0.452  0.079000       9.3
# 27                               Burundi     0.433  0.032000      11.1
# 30                              Cameroon     0.563  0.065000      12.1
# 32              Central African Republic     0.397  0.041000       7.6
# 33                                  Chad     0.398  0.037000       7.3
# 39    Congo (Democratic Republic of the)     0.480  0.061000       9.7
# 45                         C�te d'Ivoire     0.538  0.076000      10.0
# 57                              Ethiopia     0.485  0.074000       8.8
# 62                                Gambia     0.496  0.040000       9.9
# 69                                Guinea     0.477  0.069000       9.4
# 70                         Guinea-Bissau     0.480  0.050000      10.6
# 72                                 Haiti     0.510  0.040000       9.7
# 97                               Liberia     0.480  0.028000       9.6
# 102                           Madagascar     0.528  0.018000      10.2
# 103                               Malawi     0.483  0.063000      11.2
# 106                                 Mali     0.434  0.033000       7.5
# 109                           Mauritania     0.546  0.044000       8.6
# 117                           Mozambique     0.456  0.062000      10.0
# 124                                Niger     0.394  0.073000       6.5
# 125                              Nigeria     0.539  0.049000      10.0
# 133                     Papua New Guinea     0.555  0.043000      10.2
# 142                               Rwanda     0.543  0.066000      11.2
# 149                              Senegal     0.512  0.051000       8.6
# 152                         Sierra Leone     0.452  0.058000      10.2
# 158                          South Sudan     0.433  0.040715       5.3
# 161                                Sudan     0.510  0.042000       7.9
# 167        Tanzania (United Republic of)     0.529  0.055000       8.1
# 169                          Timor-Leste     0.606 -0.005000      12.6
# 176                               Uganda     0.544  0.057000      11.4
# 186                                Yemen     0.470 -0.032000       8.8
# 187                               Zambia     0.584  0.067000      11.5
#
#       edu_var  pov_index pov_class
# 0    1.300000      0.272      poor
# 4    2.800000      0.282      poor
# 18   2.000000      0.368      poor
# 26   3.000000      0.519      poor
# 27   1.300000      0.403      poor
# 30   2.200001      0.243      poor
# 32   1.100000      0.465      poor
# 33   0.600000      0.533      poor
# 39   0.800000      0.331      poor
# 45   1.700000      0.236      poor
# 57   0.700000      0.489      poor
# 62   1.099999      0.204      poor
# 69   1.299999      0.373      poor
# 70   0.900001      0.372      poor
# 72   1.099999      0.200      poor
# 97   0.000000      0.320      poor
# 102  0.000000      0.384      poor
# 103  1.000000      0.243      poor
# 106  0.100000      0.376      poor
# 109  1.000000      0.261      poor
# 117  0.600000      0.411      poor
# 124  2.100000      0.590      poor
# 125  0.500000      0.254      poor
# 133  0.900000      0.263      poor
# 142  0.200000      0.259      poor
# 149  0.900001      0.288      poor
# 152  1.500000      0.297      poor
# 158  0.824599      0.580      poor
# 161  0.600000      0.279      poor
# 167 -0.599999      0.273      poor
# 169  0.800000      0.210      poor
# 176  0.500000      0.269      poor
# 186  0.300000      0.241      poor
# 187  0.500000      0.232      poor

# %%
final_df = df.drop(['Country'], axis = 1)

# %%
# Create dummies variables for the pov_class
final_df = pd.get_dummies(final_df, prefix = 'bool', drop_first = True)

# %%
# Extracting the features and labels
X = final_df.drop(['bool_poor'], axis = 1)
y =final_df.bool_poor

# %%
# Scaling data and performing PCA to identify the most meaningful features
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
scaler = StandardScaler()
pca = PCA()
pipeline = make_pipeline(scaler, pca)
pipeline.fit(X)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('pca', PCA())])

# %%
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('Variance')
plt.xticks(features)
plt.show()

# %%
pca2 = PCA()
pca2.fit(X)
pca2_features = pca2.transform(X)
print(pca2_features.shape)
# Out:
# (189, 5)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(pca2_features, y, test_size=0.25)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-108c0644ac26> in <module>
# ----> 1 X_test_scaled = scaler.transform(X_test)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#     884                                 accept_sparse='csr', copy=copy,
#     885                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 886                                 force_all_finite='allow-nan')
#     887
#     888         if sparse.issparse(X):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     435
#     436         if check_params.get('ensure_2d', True):
# --> 437             self._check_n_features(X, reset=reset)
#     438
#     439         return out
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     364         if n_features != self.n_features_in_:
#     365             raise ValueError(
# --> 366                 f"X has {n_features} features, but {self.__class__.__name__} "
#     367                 f"is expecting {self.n_features_in_} features as input.")
#     368
#
# ValueError: X has 3 features, but StandardScaler is expecting 5 features as input.
